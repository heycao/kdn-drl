# %%
# !git clone https://github.com/heycao/kdn-drl.git
# %cd kdn-drl
# !wget https://knowledgedefinednetworking.org/data/datasets_v0/nsfnet.tar.gz
# !mkdir -p data
# !tar -xzf nsfnet.tar.gz -C data
# !pip install -r requirements.txt

# %% [markdown]
# # Naive Deflection

# %%
# !python main.py --total_timesteps 1024 --num_samples 100 --env_type base --data_filter oracle

# %% [markdown]
# # Masked Deflection

# %%
# !python main.py --total_timesteps 1024 --num_samples 100 --env_type masked --data_filter oracle
